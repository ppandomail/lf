# %% [markdown]
# # TP ASDB
# ---

# %% [markdown]
# Verificar si la construcción aaabddccd es correcta
#
# $$S \rightarrow aST \mid b$$
# $$T \rightarrow cT \mid d$$

# %% [markdown]
# Verificar si la construcción 01210 es correcta
#
# $$S \rightarrow 0S0 \mid 1S1 \mid 2$$

# %% [markdown]
# Verificar si la construcción 11100 es correcta. L = {palabras están formadas por un conjunto de 1´s seguidos de un conjunto de 0´s, donde la cantidad de símbolos 1 debe ser impar  y la cantidad de  símbolos 0 debe ser par}

# %% [markdown]
# $$S \rightarrow AA \mid 0$$
# $$A \rightarrow SS \mid 1$$

# %% [markdown]
# $$S \rightarrow z \mid xSzz$$
