# %% [markdown]
# # TP ASAB
# ---

# %% [markdown]
# Cadena: $aaabddccd$
#
# $$S \rightarrow aST \mid b$$
# $$T \rightarrow cT \mid d$$

# %% [markdown]
# Cadena: $aacbb$
#
# $$S \rightarrow aaRbb \mid ab$$
# $$R \rightarrow c$$

# %% [markdown]
# Cadena: $zxzxyzyz$
#
# $$S \rightarrow zABz$$
# $$A \rightarrow xAx \mid z$$
# $$B \rightarrow yBy \mid z$$

# %% [markdown]
# Cadena: $iiaea$
#
# $$S \rightarrow iSeS \mid iS \mid a$$

# %% [markdown]
# Cadena: $0101011$
#
# $$S \rightarrow 0A1 \mid 1A0 \mid 1$$
# $$A \rightarrow 0S0 \mid 1A1 \mid 0$$

# %% [markdown]
# Cadena: $011110$
#
# $$S \rightarrow 0A0$$
# $$A \rightarrow 1A \mid 1$$

# %% [markdown]
# Cadena: $idbeginotroendend$
#
# $$S \rightarrow id X \mid id Y end$$
# $$X \rightarrow otro \mid \lambda$$
# $$Y \rightarrow begin X end \mid \lambda$$

# %% [markdown]
# Cadena: $var \, id , id : int ;$
#
# $$D \rightarrow var V : T ;$$
# $$V \rightarrow id , V | id$$
# $$T \rightarrow int | bool$$
