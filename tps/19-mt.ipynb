# %% [markdown]
# # TP MT
# ---

# %% [markdown]
# ## MT-aceptable unicinta

# %% [markdown]
# Palabras con cantidad par de 0’s

# %% [markdown]
# Palabras que comienzan y terminan con el mismo símbolo

# %% [markdown]
# Palabras del LR representado por la ER $aba^*$

# %% [markdown]
# Palabras de parejas de paréntesis

# %% [markdown]
# Palabras que contengan 1’s y/o 0’s pero no contengan 3 ceros seguidos

# %% [markdown]
# Palabras con un número par de x. Ejemplo xx, xxxx, ...

# %% [markdown]
# Palabras de 1’s cuya longitud es una potencia de 2

# %% [markdown]
# ![MT-uni-pot2.png](attachment:3e1274b2-cc96-4219-9a79-7f4d589469e6.png)

# %% [markdown]
# Palabras con cantidad de aes igual a cantidad de bes

# %% [markdown]
# Palabras con cantidad de aes igual a cantidad de bes e igual a cantidad de ces

# %% [markdown]
# $\{wb / w \in \{a, b\}^*\}$

# %% [markdown]
# $\{yx^nzy / n ≥ 0\}$

# %% [markdown]
# $\{w\#w / w \in \{a, b\}^+\}$

# %% [markdown]
# $\{xww^{-1}y / x, y, w \in \{a, b\}^+ \wedge |x| ≥ |y|\}$

# %% [markdown]
# $\{ww / w \in \{a, b\}^*\}$

# %% [markdown]
# $\{a^nb^kd^{2n}e^{n+1} / k, n ≥ 1\}$ sobre $\Sigma = \{a, b, c, d, e\}$

# %% [markdown]
# $\{a^{i+2}b^jc^{2i}d^j / i, j ≥ 0\}$ sobre $\Sigma = \{a, b, c, d, e\}$

# %% [markdown]
# $\{b^{2r}a^{n+1}b^nd^je^{r+1} / n, r ≥ 0 \wedge j > r\}$ sobre $\Sigma = \{a, b, c, d, e\}$

# %% [markdown]
# $\{a^{n+1}b^nd^ne^k/ n ≥ 0 \wedge k > n\}$ sobre $\Sigma = \{a, b, c, d, e\}$

# %% [markdown]
# $\{a^{2n}d^{s+1}b^ke^n/ s ≥ 0 \wedge n, k > 0 \wedge k ≠n\}$ sobre $\Sigma = \{a, b, c, d, e\}$

# %% [markdown]
# $\{a^{p+1}d^{2n}b^ne^{2k+1} / p, k ≥ 0 \wedge n > p\}$ sobre $\Sigma = \{a, b, c, d, e\}$

# %% [markdown]
# $\{a^nb^{2k+1}d^{p+1}c^k / p, k ≥ 0 \wedge n > p\} \cup \{a^nb^{2k+1}e^{2n} / n, k > 0\}$ sobre $\Sigma = \{a, b, c, d, e\}$

# %% [markdown]
# ## MT-aceptable multicinta

# %% [markdown]
# $\{a^nb^{2n}/ n ≥ 1\}$

# %% [markdown]
# ![MT-multi-anb2n.png](attachment:8fea21d8-87ce-4b15-8a3d-3ad6c80d4727.png)

# %% [markdown]
# $\{a^nb^nc^{n+1} / n ≥ 1\}$

# %% [markdown]
# $\{ww^{-1} / w \in \{a, b\}^+\}$
