# %% [markdown]
# # UNIVERSIDAD NACIONAL DE HURLINGHAM
# ## Inst. de Tecnología e Ingeniería
# ### LENGUAJES FORMALES Y AUTÓMATAS
# #### Prof: Mag. Ing. Pablo Pandolfo
# #### Examen ??? - Marzo 2026

# %% [markdown]
# * **ALUMNO**:
# * **DNI**:

# %% [markdown]
# #### NOTA: EL EXAMEN ESCRITO ES UN DOCUMENTO DE GRAN IMPORTANCIA PARA LA EVALUACIÓN DE LOS CONOCIMIENTOS ADQUIRIDOS, POR LO TANTO, SE SOLICITA LEER ATENTAMENTE LO SIGUIENTE
#
# * Responda claramente cada punto, detallando con la mayor precisión posible lo solicitado.
# * Sea prolijo y ordenado en el desarrollo de los temas.
# * Sea cuidadoso con las faltas de ortografía y sus oraciones.
# * No desarrollar el examen en lápiz.
# * Aprobación del examen: Con nota mayor o igual a 4 (cuatro)
# * Condiciones de aprobación: 60%
# * Duración de examen: 2 horas.

# %% [markdown]
# 1. **[2 puntos]** Defínase y grafíquese el AFD equivalente a el AFND (mostrar paso a paso el algoritmo visto en clase):
#     * $\Sigma = \{a, c, d\}$
#     * $Q = \{q0, q1, q2, q3, q4\}$
#     * $q0 = q0$
#     * $F = \{q4\}$
#     * $\Delta = \{(q0,a)=q1, (q0, c)=q4, (q1,c)=q1, (q1,c)=q2, (q1,c)=q4, (q2,d)=q2, (q2,d)=q3, (q3,d)=q1, (q4,c)=q0\}$

# %% [markdown]
# 2. **[1 punto]** Calcúlese la ER del AF anterior (mostrar paso a paso el algoritmo vissto en clase)

# %% [markdown]
# 3. **[1 punto]** Defínase por comprensión simbólica el el lenguaje complemento del lenguaje anterior

# %% [markdown]
# 4. **[2 puntos]** Diséñese GIC en notación BNF para describir la definición de listas en Prolog. Asumir que los identificadores son terminales (id). Los corchetes y comas son terminales. Una lista en el lenguaje PROLOG se puede representar como una secuencia de elementos encerrados entre corchetes y separados por comas. Los elementos de la lista pueden ser a su vez listas. De esta manera, los siguientes son ejemplos de listas:
#     * [id]
#     * [ ]
#     * [id, [id, id], id]
#     * [ [ ], [id, [id], id,  [ ] ] ]

# %% [markdown]
# 5. **[2 puntos]** Diséñese AP por vaciado de pila que reconoce el lenguaje del ejercicio anterior

# %% [markdown]
# 6. **[2 puntos]** Diséñese una Máquina de Turing que acepte cadenas pertenecientes al siguiente lenguaje:  $L = \{w \in \{x, y, z\}^* / w = x^n y^{2n} z^{4n}, n ≥ 1 \}$ ¿Qué otros modelos abstractos pueden reconocer las cadenas del lenguaje?
