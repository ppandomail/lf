# %% [markdown]
# # UNIVERSIDAD NACIONAL DE HURLINGHAM
# ## Inst. de Tecnología e Ingeniería
# ### LENGUAJES FORMALES Y AUTÓMATAS
# #### Prof: Mag. Ing. Pablo Pandolfo
# #### Segundo Examen Parcial - Noviembre 2025

# %% [markdown]
# * **ALUMNO**:
# * **DNI**:

# %% [markdown]
# #### NOTA: EL EXAMEN ESCRITO ES UN DOCUMENTO DE GRAN IMPORTANCIA PARA LA EVALUACIÓN DE LOS CONOCIMIENTOS ADQUIRIDOS, POR LO TANTO, SE SOLICITA LEER ATENTAMENTE LO SIGUIENTE
#
# * Responda claramente cada punto, detallando con la mayor precisión posible lo solicitado.
# * Sea prolijo y ordenado en el desarrollo de los temas.
# * Sea cuidadoso con las faltas de ortografía y sus oraciones.
# * No desarrollar el examen en lápiz.
# * Aprobación del examen: Con nota mayor o igual a 4 (cuatro)
# * Condiciones de aprobación: 60%
# * Duración de examen: 3 horas.

# %% [markdown]
# 1. **[2 puntos]** Diséñese una GIC para $L = \{a^n b^m c^{n+m} b^j a^{j+1} / n,m \geq 1; j \geq 0\}$. Sólo producciones. (Para facilitar el diseño/corrección usar los nombres de los símbolos no terminales en este orden: S, X, Y, Z, A, B, C, ...)

# %% [markdown]
# $$S \rightarrow aXcZ$$
# $$X \rightarrow aXc \mid Y$$
# $$Y \rightarrow bYc \mid bc$$
# $$Z \rightarrow bZa \mid a$$

# %% [markdown]
# 2. **[2 puntos]** Normalícese a FNC. Sólo producciones. GIC:
#
# $$S \rightarrow aXbX \mid abX \mid aXb \mid ab \mid AbA \mid bA \mid Ab \mid b$$
# $$X \rightarrow aY \mid bY \mid a \mid b$$
# $$Y \rightarrow X \mid c$$
# $$A \rightarrow Aa \mid a$$

# %% [markdown]
# $$S \rightarrow EF \mid AF \mid EB \mid AB \mid TZ \mid BZ \mid ZB \mid b$$
# $$X \rightarrow AY \mid BY \mid a \mid b$$
# $$Y \rightarrow AY \mid BY \mid a \mid b \mid c$$
# $$E \rightarrow AX$$
# $$F \rightarrow BX$$
# $$A \rightarrow a$$
# $$B \rightarrow b$$
# $$Z \rightarrow ZA \mid a$$
# $$T \rightarrow ZB$$

# %% [markdown]
# 3. **[2 puntos]** Diséñese AP (por vaciado) que reconozca **bi=i+j;j=ie**, mostrando movimientos. Sólo grafo. GIC:
# $$P \rightarrow bLe$$
# $$L \rightarrow S \mid S;L$$
# $$S \rightarrow V = E$$
# $$V \rightarrow i \mid j$$
# $$E \rightarrow V+V \mid V-V \mid V$$

# %% [markdown]
# * FNG
#
# $$P \rightarrow bLF$$
# $$L \rightarrow iIE \mid jIE \mid iIECL \mid jIECL$$
# $$V \rightarrow i \mid j$$
# $$E \rightarrow iMV \mid jMV \mid iRV \mid jRV \mid i \mid j$$
# $$F \rightarrow e$$
# $$I \rightarrow =$$
# $$C \rightarrow ;$$
# $$M \rightarrow +$$
# $$R \rightarrow -$$

# %% [markdown]
# 4. **[2 puntos]** Defínase por comprensión simbólica el L reconocido por
# $$\Gamma = \{0, 1, X, Y, □\}$$
# $$\Sigma = \{0, 1\}$$
# $$b = □$$
# $$Q = \{i, m, f\}$$
# $$q0 = i$$
# $$F = \{f\}$$
# $$\delta = \{\delta(i,1)=(i,X,R), \delta(i,0)=(m,Y,R), \delta(i,□)=(f,□,S), \delta(m,1)=(m,X,R), \delta(m,0)=(i,Y,R)\}$$

# %% [markdown]
# $L = \{(1^n 0 1^m 0 1^p)^q / n, m, p, q \geq 0\}$

# %% [markdown]
# 5. **[2 puntos]** Defínase por comprensión simbólica el L generado por
#
# $$S \rightarrow BL \mid RB$$
# $$L \rightarrow BL \mid A$$
# $$R \rightarrow RB \mid A$$
# $$A \rightarrow BAB \mid \&$$
# $$B \rightarrow \Omega \mid \Delta$$

# %% [markdown]
# $L = \{w_1 \& w_2 / w_1, w_2 \in \{\Omega, \Delta\} \wedge \mid w_1 \mid \neq \mid w_2 \mid\}$
