# %% [markdown]
# # UNIVERSIDAD NACIONAL DE HURLINGHAM
# ## Inst. de Tecnología e Ingeniería
# ### LENGUAJES FORMALES Y AUTÓMATAS
# #### Prof: Mag. Ing. Pablo Pandolfo
# #### Examen Integrador - Diciembre 2025

# %% [markdown]
# * **ALUMNO**:
# * **DNI**:

# %% [markdown]
# #### NOTA: EL EXAMEN ESCRITO ES UN DOCUMENTO DE GRAN IMPORTANCIA PARA LA EVALUACIÓN DE LOS CONOCIMIENTOS ADQUIRIDOS, POR LO TANTO, SE SOLICITA LEER ATENTAMENTE LO SIGUIENTE
#
# * Responda claramente cada punto, detallando con la mayor precisión posible lo solicitado.
# * Sea prolijo y ordenado en el desarrollo de los temas.
# * Sea cuidadoso con las faltas de ortografía y sus oraciones.
# * No desarrollar el examen en lápiz.
# * Aprobación del examen: Con nota mayor o igual a 4 (cuatro)
# * Condiciones de aprobación: 60%
# * Duración de examen: 2,5 horas.

# %% [markdown]
# 1. **[1 punto]** Explíquese $L^* = \{\lambda\} \cup L^+$

# %% [markdown]
# 2. **[1 punto]** Explíquese LR $\subset$ LIC

# %% [markdown]
# 3. **[2 puntos]** Diséñese GIC bien formada del metalenguaje de GR. Axioma es S. $\mid \Sigma_T \cup \Sigma_N \mid <= 5$

# %% [markdown]
# 4. **[1 punto]** Derívese verticalmente $w = S\rightarrow C0 \; S \rightarrow D1 \; C \rightarrow 1 \; D \rightarrow 1$

# %% [markdown]
# 5. **[1 punto]** Diséñese ER con todos los operadores y ER' del complemento del lenguaje representado por ER

# %% [markdown]
# 6. **[1 punto]** Respóndase: Como reconocer un LR infinito si se tiene un número finito de estados en un AF

# %% [markdown]
# 7. **[1 punto]** Respóndase: Como reconocer un LR infinito si se tiene un número finito de estados en un AJustifíquese: En pumping lemma w se descompone en 3 segmentos

# %% [markdown]
# 8. **[1 punto]** Diséñese AP por estado final que reconoce programas que empiezan con 'begin' y terminan con 'end'. El cuerpo del programa es una secuencia de 0 o más instrucciones. Defina instrucciones donde hayan expresiones

# %% [markdown]
# 9. **[1 punto]** Defínase por comprensión simbólica el lenguaje formal reconocido por la MT
#
# ```
# init: qc
# accept: qa
# qc,0,_
# qc,0,0,>,>
# qc,1,_
# qc,1,1,>,>
# qc,_,_
# qr,_,_,-,<
# qr,_,0
# qr,_,0,-,<
# qr,_,1
# qr,_,1,-,<
# qr,_,_
# qt,_,_,<,>
# qt,0,0
# qt,0,0,<,>
# qt,1,1
# qt,1,1,<,>
# qt,_,_
# qa,_,_,-,-
# ```
