# %% [markdown]
# #### UNO - LENGUAJES FORMALES - Segundo Parcial (23 de junio 2026)
# ##### Prof: Mag. Ing. Pablo Pandolfo / Lic. Pablo Rechimon

# %% [markdown]
# * Condiciones de aprobación: 60% de práctica + 60% de teoria
# * Duración: 2,5 horas
# ---

# %% [markdown]
# 1. [1] Diséñese una GIC bien formada que genere las palabras de $L = \{w \in \{a, b, c\}^* / w = w^R \wedge |w|_c \: es \: par\}$. Sólo producciones

# %% [markdown]
# $$S \rightarrow aSa \mid bSb \mid cCc \mid \lambda$$
# $$C \rightarrow cCc \mid cc$$

# %% [markdown]
# 2. [1] Defínase por comprensión simbólica el lenguaje generado por la GIC:
# $<\{a, b, c\}, \{S, M, P\}, S, \{S \rightarrow aSb, S \rightarrow \lambda, S \rightarrow M$
# $M \rightarrow cM, M \rightarrow P, M \rightarrow c, P \rightarrow dPd, P \rightarrow dd\}>$

# %% [markdown]
# $$L = \{a^n c^m d^{2k} b^n / n,m,k ≥ 0\}$$

# %% [markdown]
# 3. [1] Diséñese AP por vaciado de pila del lenguaje anterior.

# %% [markdown]
# * FNG:
#
# $$S \rightarrow aSB \mid \lambda \mid cM \mid dPD \mid dD \mid c$$
# $$M \rightarrow cM \mid dPD \mid dD \mid c$$
# $$P \rightarrow dPD \mid dD$$
# $$B \rightarrow b$$
# $$D \rightarrow d$$
#
# * $\delta(q0, a) = (q0, S, SB)$
# * ...

# %% [markdown]
# 4. [1] Obténgase la tabla de parsing para la cadena: $a c d d b$

# %% [markdown]
# | Pila      | Cadena    | Transición                         |
# | --        | --        | --                                 |
# | $S$       | $acddb$   | $\delta(q0, a) = (q0, S, SB)$      |
# | $BS$      | $cddb$    | $\delta(q0, c) = (q0, S, M)$       |
# | $BM$      | $ddb$     | $\delta(q0, d) = (q0, M, D)$       |
# | $BD$      | $db$      | $\delta(q0, d) = (q0, D, \lambda)$ |
# | $B$       | $b$       | $\delta(q0, b) = (q0, B, \lambda)$ |
# | $\lambda$ | $\lambda$ | accept                             |

# %% [markdown]
# 5. [1] Determínese el lenguaje que reconoce la MT:
#
# | Estado \ Símbolo | a              | b              | X              | ␣ (blanco)       |
# |------------------|----------------|----------------|----------------|------------------|
# | q0               | (q_a, X, R)    | (q_b, X, R)    | (q0, X, R)     | (q_acept, ␣, R)  |
# | q_a              | (q_a, a, R)    | (q_a, b, R)    | (q_a, X, R)    | (q_ret, ␣, L)    |
# | q_b              | (q_b, b, R)    | (q_b, b, R)    | (q_b, X, R)    | (q_ret, ␣, L)    |
# | q_ret            | (q_ret, a, L)  | (q_ret, b, L)  | (q_ret, X, L)  | (q0, ␣, R)       |

# %% [markdown]
# $$L = \{w \in \{a, b\}^* / w = w^R\}$$

# %% [markdown]
# 6. [5] Respóndase **V** o **F**
#     * En pumping lemma de LIC, $w = uvxyz$, los segmentos que se bombean conjuntamente son $v$ e $y$
#     * El $L = \{a^n b^n c^n / n ≥ 0\}$ es LIC
#     * Todo LIC puede ser reconocido por un APND
#     * En esta configuración de MT: $0q1$, la cabeza se encuentra sobre $1$
#     * $\delta(q0,a) = (q1, X, R)$ se reescribe en Turing Machine Simulator: $q0, a$ y en otra línea $R, q1, X$

# %% [markdown]
# $$VFVVF$$
