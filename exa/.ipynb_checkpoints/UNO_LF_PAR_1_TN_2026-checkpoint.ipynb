# %% [markdown]
# #### UNO - LENGUAJES FORMALES - Primer Parcial (28 de abril 2026)
# ##### Prof: Mag. Ing. Pablo Pandolfo / Lic. Pablo Rechimon

# %% [markdown]
# * Condiciones de aprobación: 60% de práctica + 60% de teoria
# * Duración: 2,5 horas
# ---

# %% [markdown]
# 1. [1] Diséñese una GR bien formada que genere las palabras del lenguaje $L = \{w / w = x^{a+1} y x^{b+2} z^c, a ≥ 1, b ≥ 1, c ≥ 0 \}$, considerando el siguiente alfabeto $\Sigma = \{x, y, z\}$. Sólo producciones. (Para facilitar el diseño/correción usar los nombre de los símbolos no terminales en este orden: S, A, B, C, D, ...)

# %% [markdown]
# 2. [1] Defínase por comprensión simbólica el lenguaje generado por la GR:
# $<\{unahur, uno\}, \{A, C, I, B\}, I, \{A \rightarrow unahurI, A \rightarrow unoB,$
# $C \rightarrow unahurB, C \rightarrow unoI, I \rightarrow unahurA, I \rightarrow unoC,$
# $I \rightarrow uno,$ $B \rightarrow unahurC, B \rightarrow unoA, B \rightarrow unahur\}>$

# %% [markdown]
# 3. [1] Defínase por comprensión coloquial el lenguaje complemento del lenguaje anterior.

# %% [markdown]
# 4. [1] Obténgase la ER que representa al lenguaje $L_1 \cup L_2$ sobre el alfabeto $\Sigma = \{x, y\}$, donde $L_1 = \{w / w = y^{3a} x^{b+1} y^{2c+1}, a ≥ 0, b ≥ 0, c ≥ 1\}$ y $L_2 = \{w$ son las cadenas que contienen $xyx$ como subcadena$\}$. Sólo usar operadores básicos.

# %% [markdown]
# 5. [1] Diséñese el AFD mínimo (grafo) que reconoce el lenguaje complemento de $L_1^R$

# %% [markdown]
# 6. [5] Respóndase **V** o **F**
#     * Todo lenguaje que puede ser descrito por una ER también puede ser reconocido por un AF
#     * Las GR generan exactamente el mismo conjunto de lenguajes que los AFD y AFN
#     * El conjunto que contiene sólo la cadena vacía es regular
#     * Una palabra es una secuencia infinita de símbolos concatenados tomados de un alfabeto
#     * El lenguaje de todas las cadenas binarias que contienen igual número de ceros y unos es regular
