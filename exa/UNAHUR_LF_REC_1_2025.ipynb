# %% [markdown]
# # UNIVERSIDAD NACIONAL DE HURLINGHAM
# ## Inst. de Tecnología e Ingeniería
# ### LENGUAJES FORMALES Y AUTÓMATAS
# #### Prof: Mag. Ing. Pablo Pandolfo
# #### Recuperatorio Primer Parcial - Noviembre 2025

# %% [markdown]
# * **ALUMNO**:
# * **DNI**:

# %% [markdown]
# #### NOTA: EL EXAMEN ESCRITO ES UN DOCUMENTO DE GRAN IMPORTANCIA PARA LA EVALUACIÓN DE LOS CONOCIMIENTOS ADQUIRIDOS, POR LO TANTO, SE SOLICITA LEER ATENTAMENTE LO SIGUIENTE
#
# * Responda claramente cada punto, detallando con la mayor precisión posible lo solicitado.
# * Sea prolijo y ordenado en el desarrollo de los temas.
# * Sea cuidadoso con las faltas de ortografía y sus oraciones.
# * No desarrollar el examen en lápiz.
# * Aprobación del examen: Con nota mayor o igual a 4 (cuatro)
# * Condiciones de aprobación: 60%
# * Duración de examen: 3 horas.

# %% [markdown]
# 1. **[3.3 puntos]** Constrúyase AFDmin para $L = \{x^{2n} y^{2k+1} / n \geq 1; k \geq 0\} \cup \{xw / w \in \{x, z\}^*; w$ contiene $zx\}$. Mostrar algoritmos

# %% [markdown]
# | Q  | x  | y  | z  |
# | -- | -- | -- | -- |
# | >A | B  | -  | -  |
# | B  | C  | -  | G  |
# | C  | B  | D  | G  |
# | *D | -  | E  | -  |
# | E  | -  | D  | -  |
# | G  | H  | -  | G  |
# | *H | H  | -  | H  |
#
# $$\mid Q \mid = 7$$

# %% [markdown]
# 2. **[3.3 puntos]** Diséñese usando operadores básicos ER de $L^c$ donde $L = \{w / w \in \{1, 2\} \wedge$ la suma de símbolos en $w$ es múltiplo de 4$\}$. Mostrar algoritmo de complemento de AF

# %% [markdown]
# | L    | 1  | 2  |
# | --   | -- | -- |
# | >*q0 | q1 | q2 |
# | q1   | q2 | q3 |
# | q2   | q3 | q0 |
# | q3   | q0 | q1 |
#
# |$L^c$ | 1  | 2  |
# | --   | -- | -- |
# | >q0  | q1 | q2 |
# | *q1  | q2 | q3 |
# | *q2  | q3 | q0 |
# | *q3  | q0 | q1 |
#
# * ALT1: $(22 \mid 1111)^* (1 \mid 2 \mid 11 \mid 12 \mid 21 \mid 111 \mid 122\mid 212 \mid 221 \mid 222)$
# * ALT2: $(1111 \mid 112 \mid 121 \mid 211 \mid 22)^* (1 \mid 2 \mid 11 \mid 12 \mid 21 \mid 111)$

# %% [markdown]
# 3. **[3.3 puntos]** Diséñese GR que genere las palabras del lenguaje concatenación $L_1L_2$, donde $L_1 = \{w / w$ es cualquier palabra, excepto $01, 101, 0100\}$ y $L_2 = \{w / w$ tiene cualquier longitud compuestas por las subcadenas $1, 01$ y $001$ y finalizadas con una subcadena de $0s$ con longitud menor a 3$\}$. Ambos lenguajes con $\Sigma = \{0, 1\}$

# %% [markdown]
# $$S \rightarrow 0S \mid 1S \mid \lambda$$
